# %%
import pandas as pd
df=pd.read_csv('student_habits_performance.csv')

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [1000 rows x 16 columns]

# %%
df.shape
# Out:
# (1000, 16)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum()
#df.isna().sum().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df= df.dropna() # dropping the duplicated colum and assignin the new df

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# to escape from warnings

import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
df.describe(include=object)
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
# categorical_columns = ["gender", "part_time_job", "diet_quality", "parental_eduaction_level", "internet_quality", "extracurricular_participation"]

# %%
df.describe(include=object).columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
 categorical_columns =[ 'gender', 'part_time_job', 'diet_quality', 'parental_education_level', 'internet_quality','extracurricular_participation']

# %%
for col in categorical_columns:
    print(f" value counts for {col}: \n {df[col].value_counts()}")
# Out:
#  value counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
#  value counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
#  value counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
#  value counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
#  value counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
#  value counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor= "black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_columns:
    sns.countplot(data=df , x=col)
    plt.title(f"distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot= True ,cmap= "coolwarm", fmt=".2f")
plt.title("correlation matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating', ]

# %%
for feature in num_features:
    sns.scatterplot(data=df , x= feature , y=  "exam_score")
    plt.show()

# %%
for col in categorical_columns:
    sns.boxplot(data= df, x= col , y= "exam_score")
    plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
features = ['study_hours_per_day',  'attendance_percentage', 'mental_health_rating' ,'sleep_hours', 'part_time_job' ]

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# 1            4.6            No       100.0
# 2            8.0            No        34.3
# 3            9.2            No        26.8
# 4            4.9            No        66.4
# ..           ...           ...         ...
# 995          7.5            No        76.1
# 996          6.8           Yes        65.9
# 997          6.5            No        64.4
# 998          7.6           Yes        69.7
# 999          7.1            No        74.9
#
# [909 rows x 6 columns]

# %%
le =LabelEncoder()

# %%
df_model["part_time_job"] = le.fit_transform(df_model["part_time_job"])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# 1            4.6              0       100.0
# 2            8.0              0        34.3
# 3            9.2              0        26.8
# 4            4.9              0        66.4
# ..           ...            ...         ...
# 995          7.5              0        76.1
# 996          6.8              1        65.9
# 997          6.5              0        64.4
# 998          7.6              1        69.7
# 999          7.1              0        74.9
#
# [909 rows x 6 columns]

# %%
X= df_model[features]

# %%
y= df_model[target]

# %%
X_train , X_test, y_train , y_test =train_test_split(X, y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(X_train)
# Out:
# 727

# %%
models = {
    "LinearRegression": {
        "model" : LinearRegression(),
        "params" : {}
    },
    "DecisionTree" : {
        "model" : DecisionTreeRegressor(),
        "params" : {"max_depth" : [3,5,10] ,"min_samples_split" : [2,5]}
    }, 
    "RandomForest" : {
        "model" : RandomForestRegressor(),
        "params" : { "n_estimators": [50,100], "max_depth" : [5,10] }
        
    }
    
}

# %%
best_models= []

# %%
for name, config in models.items():
    print(f"training {name}")

    grid = GridSearchCV(config["model"] , config["params"], cv=5 ,scoring ="neg_mean_squared_error")
    grid.fit(X_train, y_train)

    y_pred= grid.predict(X_test)
    rmse =np.sqrt(mean_squared_error(y_test, y_pred))
    r2= r2_score(y_test, y_pred)

    best_models.append({
        "model" : name,
        "best_params" : grid.best_params_,
        "rmse" : rmse,
        "r2" : r2
    })
# Out:
# training LinearRegression
# training DecisionTree
# training RandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(6.807232042180056),
#   'r2': 0.8268759758697644},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 5},
#   'rmse': np.float64(8.357501328273164),
#   'r2': 0.7390428881689368},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 5, 'n_estimators': 50},
#   'rmse': np.float64(7.150680331197045),
#   'r2': 0.808965874115906}]

# %%
result_df = pd.DataFrame(best_models)

# %%
result_df.sort_values(by= "rmse")
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  6.807232
# 2      RandomForest      {'max_depth': 5, 'n_estimators': 50}  7.150680
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.357501
#
#          r2
# 0  0.826876
# 2  0.808966
# 1  0.739043

# %%
best_row = result_df.sort_values(by = "rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   6.807232
# r2                     0.826876
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config =models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
import joblib

# %%
joblib.dump(final_model, "best_model.pkl")
# Out:
# ['best_model.pkl']

# %%
joblib.load("best_model.pkl").predict(X_test)
# Out:
# array([ 80.15376333,  79.32808448,  62.91212161,  78.2264766 ,
#         63.3153885 ,  76.68472104,  83.72423392,  73.63843002,
#         86.71282094,  66.21786679,  64.35623557,  60.91996362,
#         80.46322951,  68.8899433 ,  74.8589124 ,  68.33827278,
#         70.20854282,  69.09467311,  74.44479129,  60.44639729,
#         69.96011467,  66.22583241,  68.8414418 ,  82.19382145,
#         77.0077602 ,  75.7404905 ,  43.87777281,  66.0866954 ,
#        101.01138266,  89.8219083 ,  72.47549093,  94.48143692,
#         57.98249864,  63.52287934,  68.38334944,  74.54938602,
#         97.04729563,  22.90568775,  79.75220639,  54.84649087,
#         50.42847388,  42.51199279,  73.76225891,  61.7913346 ,
#         85.2652158 ,  65.9872718 ,  71.74445088,  62.73931128,
#         69.51599848,  37.08526345,  67.60617053,  80.45227491,
#         74.55553431,  86.19114402,  67.77673736,  84.17072978,
#         38.17280081,  65.54214455,  66.53984381,  53.62059091,
#         81.85562938, 109.86076479,  61.47538447,  74.29479694,
#         57.77560058,  93.02561935,  84.00104813,  56.00371918,
#        104.70803339,  84.70133971,  63.64137371,  79.77697389,
#         92.44727813,  64.87101299,  60.61304698,  91.54818993,
#         70.22148331,  39.6867241 ,  77.66986207,  64.48227953,
#         74.18329974,  79.36878895,  77.2704704 ,  37.70865932,
#         62.717919  ,  95.41329797,  60.05075545,  63.46863323,
#         94.4572444 ,  83.07636937,  82.34026337,  69.95368226,
#         54.97205488,  63.74550402,  76.75958523,  67.09112318,
#         62.92406585,  63.09137222,  71.56094773,  97.56842667,
#         72.40322861,  86.75373513,  79.94294863,  66.85495635,
#         59.41323383,  62.03082708,  58.48066121,  84.20309395,
#        100.91762465,  61.88623029,  78.71971636,  44.87641598,
#         72.17523691,  39.79507284,  96.19409343,  54.52840609,
#         76.45016176,  81.50258474, 103.39848608,  42.98530424,
#         74.5771561 ,  82.51642869,  97.71483999,  91.69729711,
#         76.48969124,  57.45957817,  87.76819727,  85.9407813 ,
#         49.2095591 ,  90.35284716,  57.82131369,  74.1183648 ,
#         73.17116424,  54.1048007 ,  70.21478147,  64.81002362,
#         77.42086604,  62.07233324,  53.21270007,  69.0659914 ,
#         87.18702105,  71.06624832,  61.60372745,  60.78719557,
#         96.72667692,  62.21932629,  96.07396925,  72.41928765,
#         70.10700083,  56.21699206,  53.35891573,  73.37721953,
#         72.25779551,  39.63541895,  81.43685695,  60.92025364,
#         68.96605494,  54.1809859 ,  86.35977735,  70.53217871,
#         69.14617842,  85.76356001,  55.74098408,  97.86319106,
#         91.82549796,  68.66172969,  46.98667506,  59.80546684,
#         81.14151653,  66.57818379,  86.38678834,  58.14930281,
#         81.11499936,  44.85583341,  54.8674567 ,  78.33524881,
#         43.50243593,  53.80314099,  66.5155005 ,  61.10409062,
#         89.51393611,  64.7719743 ])
